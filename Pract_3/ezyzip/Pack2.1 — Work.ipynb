# %% [markdown]
# # Практическое занятие №2.1
#
# РТУ МИРЭА

# %% [markdown]
# # Раздел 1

# %% [markdown]
# Если вы рисуете прямую линию на плоскости, плоскость делится на две области. Например, если вы проведете две прямые линии параллельно, вы получите три области, а если вы проведете одну к другой вертикально, вы получите 4 области.
# Напишите программу на Python, чтобы создать максимальное количество областей, полученных путем рисования n заданных прямых линий.
#
# Вход:
# (1 ≤ n ≤ 10 000)
# Введите количество прямых линий (o для выхода):
# 5
# Количество регионов:
# 16

# %% [markdown]
# Задание 1: (Уровень сложности низкий).

# %% [markdown]
# Задача: 1.2 (Уровень средний).
# Игра - «Камень, ножницы, бумага»

# %% [markdown]
# Эта программа «Камень, ножницы, бумага» имитирует всемирно популярную игру с функциями и условными операторами.
#
# Как один из многих проектов кодирования Python, который импортирует дополнительные библиотеки, эта программа использует модули random, os и re из стандартной библиотеки.
#
# Эта идея проекта Python предлагает пользователю сделать первый шаг, передав символ, представляющий камень, бумагу или ножницы. После оценки входной строки условная логика проверяет победителя.

# %% [markdown]
# # Алгоритмическая игра DandyBot

# %% [markdown]
# 1.3 - (уровень сложности: низкий) Все уровни +1
#
# Скачайте DandyBot. Код для своего игрока записывается в файле user_bot.py. Игра запускается с помощью main.py.
#
# Вот простой пример содержимого user_bot.py:

# %%
def script(check, x, y):
    return 'right'

# %% [markdown]
# Игровая логика записывается исключительно в теле функции script. В нашем случае игрок будет постоянно двигаться вправо.
#
# Полный список действий, которые можно возвращать из функции script, задающей «интеллект» игрока:

# %% [markdown]
# 1) 'up'. Двигаться вверх на клетку.
# 2) 'down'. Двигаться вниз на клетку.
# 3) 'left'. Двигаться влево на клетку.
# 4) 'right'. Двигаться вправо на клетку.
# 5) 'pass'. Ничего не делать.
# 6) 'take'. Взять золото.
# Для изучения среды есть функция check:
#
# 1) check('player', x, y). True, если какой-то игрок в позиции (x, y).
# 2) check('gold', x , y). Если золото в позиции (x, y), то вернуть его количество, иначе вернуть 0.
# 3) check('wall', x, y). True, если стена в позиции (x, y).
# 4) check('level'). Вернуть номер текущего уровня.

# %% [markdown]
# https://github.com/true-grue/DandyBot

# %% [markdown]
# Ваша задача — пройти все уровни. Дополнительно устанавливаемыми библиотеками и глобальными данными пользоваться нельзя.
#
# Если игра Вам показалась слишком простой, то попробуйте ее улучшить: упростите код, добавьте новые функции, уровни.

# %% [markdown]
# ![Alt text](screenshot.png)

# %% [markdown]
# # 2 Однострочники

# %% [markdown]
# Напишите программы-однострочники для следующих задач. Начните с наивных решений и постепенно двигайтесь в сторону решений кратких и изящных. Старайтесь попутно создавать автоматические тесты на случайных входных данных.
#
# Определитесь, в каких случаях решение-однострочник является предпочтительным, а в каких – нет.

# %% [markdown]
# 3.7. (уровень сложности: низкий)
#
# Проверить, относится ли число к числам харшад (делящиеся нацело на сумму своих цифр).
#
# 3.8. (уровень сложности: низкий)
#
# Сгенерировать случайную текстовую строку с заданным максимальным размером.

# %% [markdown]
# 3.9. (уровень сложности: средний) + 1 балл.
#
# Реализовать функцию-однострочник для RLE-сжатия. Пример работы:

# %%
rle_encode('ABBCCCDEF')
[('A', 1), ('B', 2), ('C', 3), ('D', 1), ('E', 1), ('F', 1)]

# %% [markdown]
# # Раздел 3

# %% [markdown]
# # Введение в Turtle Graphics в Python
# Изначально черепаха была просто физическим объектом, вроде робота, которого можно поместить на лист бумаги и заставить двигаться. Затем черепаха стала визуальным отображением на экране с высоким разрешением, часто изображаемым в виде любой формы.
#
# Даже в чисто графическом формате концепция черепахи может упростить представление предпринятых действий и, следовательно, того, что делает программа.
#
# Модуль черепахи обеспечивает среду, в которой черепахи перемещаются по двумерной сетке. У черепах есть положение, направление (направление, в котором черепаха смотрит) и множество возможных состояний (черепахи могут рисовать линии определенного цвета, когда они двигаются или не оставляют следов) и действий (повернуться налево или направо, двигаться вперед или назад).

# %% [markdown]
# Доп литература:
# https://docs.python.org/3/library/turtle.html

# %% [markdown]
# Задача2: (Уровень средний)
# Изобразить шахмотную доску.

# %% [markdown]
# ![Alt text](51.jpg)

# %% [markdown]
# Задача: (Уровень хакер) - 3 балла.
# Нет количества мест.

# %% [markdown]
# ![Alt text](5.jpg)

# %% [markdown]
# # 4. Ассорти из небольших задач

# %% [markdown]
# 4.1. (уровень сложности: средний) +1 балл.
#
# Вы получили зашифрованное сообщение и теперь предстоит его расшифровать:

# %%
E3238557 6204A1F8 E6537611 174E5747
5D954DA8 8C2DFE97 2911CB4C 2CB7C66B
E7F185A0 C7E3FA40 42419867 374044DF
2519F07D 5A0C24D4 F4A960C5 31159418
F2768EC7 AEAF14CF 071B2C95 C9F22699
FFB06F41 2AC90051 A53F035D 830601A7
EB475702 183BAA6F 12626744 9B75A72F
8DBFBFEC 73C1A46E FFB06F41 2AC90051
97C5E4E9 B1C26A21 DD4A3463 6B71162F
8C075668 7975D565 6D95A700 7272E637

# %% [markdown]
# Известно, что для зашифрования использовался алгоритм TEA. Известен также ключ зашифрования/расшифрования:
#
# k = [0, 4, 5, 1]
# Имеется и функция на C/C++ для расшифровки данных (v – слова данных, k – ключ):

# %%
void decrypt(uint32_t v[2], const uint32_t k[4]) {
    uint32_t v0 = v[0], v1 = v[1], sum = 0xC6EF3720, i;
    uint32_t delta = 0x9E3779B9;
    uint32_t k0 = k[0], k1 = k[1], k2 = k[2], k3 = k[3];
    for (i = 0; i < 32; i++) {
        v1 -= ((v0 << 4) + k2) ^ (v0 + sum) ^ ((v0 >> 5) + k3);
        v0 -= ((v1 << 4) + k0) ^ (v1 + sum) ^ ((v1 >> 5) + k1);
        sum -= delta;
    }
    v[0] = v0; v[1] = v1;
}

# %% [markdown]
# Остается перевести функцию decrypt на Питон и узнать, что же содержится в зашифрованном сообщении!

# %% [markdown]
# # 5. Редакционное расстояние

# %% [markdown]
# 5.1. (уровень сложности: низкий)
#
# Редакционное расстояние Хэмминга определяет минимальное число позиций, в которых нужно произвести замену символов, чтобы получить из одной последовательности длины n другую последовательность той же длины.
#
# Реализуйте функцию вычисления расстояния Хэмминга для двух чисел, на уровне замен бит.
#
# Реализуйте сначала наивную версию, а затем придумайте, как изящно написать функцию в виде однострочника с использованием средств современного Питона.
#
# Примеры работы функции:

# %%
>>> ham_dist(0b10, 0b11)
1
>>> ham_dist(0b1100, 0b0011)
4

# %% [markdown]
# 5.2. (уровень сложности: средний) +1
#
# Простейшим вариантом кода с коррекцией ошибок является код с повторением. В рассматриваемом далее случае каждый передаваемый бит со значением 1/0 представляется тройкой бит 111/000.
#
# Примеры:

# %%
>>> bin(encode_val(4, 3, 0b1011))
'0b111000111111'
>>> bin(decode_val(4, 3, 0b111_000_111_111))
'0b1011'

# %% [markdown]
# Если два исходных значения отличаются лишь в одном бите, то их закодированные варианты имеют расстояние Хэмминга равное 3:

# %%
>>> ham_dist(encode_val(4, 3, 0b1001), encode_val(4, 3, 0b1000))
3

# %% [markdown]
# Это позволяет автоматически исправлять внесенные помехи в данные в зависимости от того значения, которое является преобладающим в тройке бит.

# %%
bin(decode_val(4, 3, 0b110_010_011_101))
'0b1011'

# %% [markdown]
# Задача состоит в том, чтобы корректно декодировать и откорректировать следующее текстовое сообщение. Известно, что каждое значение в исходной последовательности является 8-битным.

# %% [markdown]
# [815608, 2064837, 2093080, 2063879, 196608, 2067983, 10457031, 1830912, 2067455, 2093116, 1044928, 2064407, 6262776, 2027968, 4423680, 2068231, 2068474, 1999352, 1019903, 2093113, 2068439, 2064455, 1831360, 1936903, 2067967, 2068456]

# %% [markdown]
# # 7. Движок для текстовых игр

# %% [markdown]
# 7.1. (уровень сложности: средний)
#
# Мир простейших текстовых игр (книг-игр, Choose Your Own Adventure) состоит из множества комнат.
#
# Каждая комната содержит:
#
# название,
# метку для перехода в эту комнату,
# описание комнаты,
# список действий со стороны игрока, приводящих к выводу сообщения и переходу в другую комнату по ее метке.
# В рассматриваемом движке для описания игрового мира используется подмножество формата Markdown.
#
# Вот простейшая игра, реализованная таким образом.
#
# Задача состоит в реализации разбора указанного формата, а также в реализации игрового процесса в режиме терминала. Разбор необходимо осуществлять построчно, с помощью регулярных выражений.
#
# Ниже показан пример сеанса игры:

# %% [markdown]
# Начало лабиринта
#
# Вы в начале лабиринта. Сможете ли из него выбраться?
#
# 1. Проход на запад.
#
# > 1
#
# ...
#
# Комната №2
#
# Вы находитесь в комнате №2.
#
# 1. Проход на запад.
# 2. Проход на восток.
#
# > 1
#
# ...
#
# Комната №3
#
# Вы находитесь в комнате №3.
#
# 1. Проход на север.
# 2. Проход на восток.
#
# >

# %% [markdown]
# 7.2. (уровень сложности: средний)
#
# Изобразите граф игрового мира с помощью генерации кода на языке Dot – представления инструмента Graphviz.
#
# Пример вывода графа для game.md:

# %% [markdown]
# https://github.com/true-grue/kispython/blob/2262e9108a8ff0f82bee818d0a8b7ba88b3233bf//data/game.md

# %% [markdown]
# ![Alt text](game_md.png)

# %% [markdown]
# 7.3. (уровень сложности: высокий) +1
#
# Переработайте игровой движок таким образом, чтобы поддерживалась генерация html-проекта для игры в Web. Поддержите также вывод графики в формате игрового мира.
#
# 7.4. (уровень сложности: высокий) +1
#
# Реализуйте инструмент для автоматической проверки игрового мира на наличие тупиков – мест, из которых нельзя добраться до завершения игры.

# %% [markdown]
# # 8. Утилиты командной строки

# %% [markdown]
# 8.1. (уровень сложности: низкий)
#
# Реализуйте аналог команды ls с помощью стандартной библиотеки Питона. Реализованная команда должна работать и в Windows, и в Linux. Поддержите как можно больше ключей ls. Для разбора аргументов командной строки используйте модуль argparse.
#
# 8.2. (уровень сложности: низкий)
#
# Реализуйте утилиту командной строки, формирующую дерево каталогов и файлов с учетом произвольной вложенности и начиная с заданного пути. Результат должен быть выдан в виде текста в формате Graphviz.
#
# 8.3. (уровень сложности: средний)
#
# Реализуйте утилиту командной строки, которая преобразует в Markdown-файле обычные кавычки в кавычки-елочки с учетом их парности. Внутри блоков кода кавычки необходимо оставлять без изменений. Если утилита была запущена без аргументов, то необходимо обрабатывать стандартный ввод.

# %% [markdown]
# # Раздел 9
# Работа с музыкой.

# %% [markdown]
# # При работе с данным разделом:
# Заранее отрегулируйте уровень шума!!!
#
# Постарайтесь использовать наушники!!!

# %% [markdown]
# # Материалы для изучения Earsketch:
# https://copyassignment.com/create-your-own-music-with-python-coding/

# %% [markdown]
# Ресурсы для глубокого изучения(дома): https://www.youtube.com/watch?v=vxz7mOu4XOM

# %% [markdown]
# Веб-ресурс для работы:
#
# https://earsketch.gatech.edu/landing/#/

# %% [markdown]
# Задание: (уровень средний).
# Создать трек по следующей композиции.
# Примеры мелоий внизу ->

# %% [markdown]
# ![Alt text](52.jpg)

# %% [markdown]
# Составить музыкальную композицию основываясь на следуюших мелодиях:
# 1)YG_NEW_HIP_HOP_PIANO_1
# 2)YG_NEW_HIP_HOP_PIANO_5
# 3)VOLUME, GAIN
# 4)EIGHT_BIT_VIDEO_GAME_LOOP_001
# 5)HIPHOP_BASSSUB_001
# 6)HIPHOP_FUNKBEAT_002
# 7)CIARA_SET_VOX_HOOK_1
# 8)YG_NEW_HIP_HOP_PIANO_5
# 9)Y11_DRUM_SAMPLES_1

# %% [markdown]
# Задача (уровень высокий) - 1 бал
#
# Не органичен.

# %% [markdown]
# 8bit:
#
# 1)clip2,2,pointA + i,pointA
#
# 2)clip3,3,pointA,pointD
#
# 3)VOLUME, GAIN
#
# 4)EIGHT_BIT_ATARI_SFX_004
#
# 5)EIGHT_BIT_ATARI_LEAD_011
#
# 6)EIGHT_BIT_ATARI_LEAD_010
#
# 7)clip1
#
# 8)DELAY, DELAY_TIME
#
# 9)VOLUME, GAIN

# %% [markdown]
# ![Alt text](53.jpg)
